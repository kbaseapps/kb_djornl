# %%
import json
import sqlite3
from collections import Counter

import pandas as pd

# %%
# %%bash
# # remove test.db and ignore the error if it does not exist
# rm test.db | exit 0

# %%
DATA_ROOT = "../exascale_data"
con = sqlite3.connect("test.db")

# %%
clusters_table = """CREATE TABLE IF NOT EXISTS clusters (
    "index" INTEGER,
    "cluster_id" TEXT,
    "cluster_prefix" TEXT,
    "node_ids" TEXT
)"""

edges_table = """CREATE TABLE IF NOT EXISTS edges (
    "index" INTEGER,
    "node1" TEXT,
    "node2" TEXT,
    "score" REAL,
    "edge_type" TEXT,
    "directed" INTEGER
)"""

nodes_table = """CREATE TABLE IF NOT EXISTS "nodes" (
"index" INTEGER,
  "GID" TEXT,
  "defline" TEXT,
  "symbols" TEXT,
  "names" TEXT,
  "KO_effect" TEXT,
  "GO" TEXT,
  "GOdesc" TEXT,
  "mapman_code" TEXT,
  "mapman_name" TEXT,
  "mapman_desc" TEXT
)"""

cur_clusters = con.execute(clusters_table)
cur_edges = con.execute(edges_table)
cur_nodes = con.execute(nodes_table)

assert cur_clusters.fetchall() == []
assert cur_edges.fetchall() == []
assert cur_nodes.fetchall() == []

columns_nodes = list(pd.read_sql("""SELECT * FROM nodes""", con).columns)
columns_nodes
# Out:
# ['index',
#  'GID',
#  'defline',
#  'symbols',
#  'names',
#  'KO_effect',
#  'GO',
#  'GOdesc',
#  'mapman_code',
#  'mapman_name',
#  'mapman_desc']

# %%
df1 = pd.read_csv(f"{DATA_ROOT}/prerelease/edge_data/mentha_AT-PPI-3702_040319.to-kbase-spec.tsv", sep="\t")
df1.head()
# Out:
#        node1      node2  score  \
# 0  AT2G18790  AT1G09530  1.000
# 1  AT4G33430  AT4G39400  1.000
# 2  AT3G20740  AT1G02580  0.999
# 3  AT5G35410  AT4G33000  0.999
# 4  AT3G62980  AT3G23050  0.999
#
#                                            edge_type  directed
# 0  protein-protein-interaction_Mentha_A_thaliana_...         1
# 1  protein-protein-interaction_Mentha_A_thaliana_...         1
# 2  protein-protein-interaction_Mentha_A_thaliana_...         1
# 3  protein-protein-interaction_Mentha_A_thaliana_...         1
# 4  protein-protein-interaction_Mentha_A_thaliana_...         1

# %%
df0 = pd.read_csv(f"{DATA_ROOT}/prerelease/edge_data/ATRM_TF_to_Target_LitCurated_01082020.to-kbase-spec.tsv", sep="\t")
df0.head()
# Out:
#        node1      node2  score  \
# 0  AT5G67420  AT4G09820      1
# 1  AT2G20180  AT4G23750      1
# 2  AT2G20180  AT1G80340      1
# 3  AT2G20180  AT2G29090      1
# 4  AT2G20180  AT2G40220      1
#
#                                            edge_type
# 0  transcription-factor-regulatory-interaction_li...
# 1  transcription-factor-regulatory-interaction_li...
# 2  transcription-factor-regulatory-interaction_li...
# 3  transcription-factor-regulatory-interaction_li...
# 4  transcription-factor-regulatory-interaction_li...

# %%
df0.to_sql("edges", con, if_exists="append")

# %%
df1.to_sql("edges", con, if_exists="append")

# %%
df2 = pd.DataFrame({'name' : ['User 4', 'User 5', 'User 6']})
df3 = pd.DataFrame(dict(letter=["a"]*len(df2)))
pd.concat([df2, df3], axis=1)
# Out:
#      name letter
# 0  User 4      a
# 1  User 5      a
# 2  User 6      a

# %%
df5 = pd.read_csv(
    f"{DATA_ROOT}/prerelease/cluster_data/out.aranetv2_subnet_AT-CX_top10percent_anno_AF_082919.abc.I2_named.tsv",
    sep="\t"
)
df6 = pd.DataFrame(dict(cluster_prefix=["markov_i2"]*len(df5))) # i2 - inflation of 2
df7 = pd.concat([df5, df6], axis=1)
df7.tail()
# Out:
#        cluster_id             node_ids cluster_prefix
# 3097  Cluster3098  AT2G20080,AT2G20660      markov_i2
# 3098  Cluster3099  AT3G62280,AT5G23210      markov_i2
# 3099  Cluster3100  AT1G75890,AT3G15630      markov_i2
# 3100  Cluster3101  AT1G67670,AT1G78710      markov_i2
# 3101  Cluster3102  AT1G54870,AT5G54740      markov_i2

# %%
pd.read_sql("""select * from clusters order by "index" desc limit 5""", con)
# Out:
# Empty DataFrame
# Columns: [index, cluster_id, cluster_prefix, node_ids]
# Index: []

# %%
df7.to_sql("clusters", con, if_exists="append")

# %%
df8 = pd.read_csv(
    f"{DATA_ROOT}/prerelease/cluster_data/out.aranetv2_subnet_AT-CX_top10percent_anno_AF_082919.abc.I4_named.tsv",
    sep="\t"
)
df9 = pd.DataFrame(dict(cluster_prefix=["markov_i4"]*len(df8))) # i4 - inflation of 4
dfx = pd.concat([df8, df9], axis=1)
dfx.tail()
# Out:
#        cluster_id             node_ids cluster_prefix
# 3688  Cluster3689  AT2G20080,AT2G20660      markov_i4
# 3689  Cluster3690  AT3G62280,AT5G23210      markov_i4
# 3690  Cluster3691  AT1G75890,AT3G15630      markov_i4
# 3691  Cluster3692  AT1G67670,AT1G78710      markov_i4
# 3692  Cluster3693  AT1G54870,AT5G54740      markov_i4

# %%
dfx.to_sql("clusters", con, if_exists="append")

# %%
pd.read_sql("""select * from clusters order by "index" desc limit 5""", con)
# Out:
#    index   cluster_id cluster_prefix             node_ids
# 0   3692  Cluster3693      markov_i4  AT1G54870,AT5G54740
# 1   3691  Cluster3692      markov_i4  AT1G67670,AT1G78710
# 2   3690  Cluster3691      markov_i4  AT1G75890,AT3G15630
# 3   3689  Cluster3690      markov_i4  AT3G62280,AT5G23210
# 4   3688  Cluster3689      markov_i4  AT2G20080,AT2G20660

# %%
df_nodes = pd.read_csv(
    f"{DATA_ROOT}/prerelease/node_tables/Ath_master_annotation_v01.txt",
    sep="\t"
)
df_nodes.to_sql("nodes", con, if_exists="replace")

# %%
# How many rows per node are there? If counts > 1 then some sort of merging is required.
pd.read_sql("""
SELECT "GID", COUNT(*) as counts
    FROM nodes
    GROUP BY "GID"
    ORDER BY count(*) DESC
    LIMIT 5
""", con)
# Out:
#     GID  counts
# 0    YI       1
# 1   YAK       1
# 2    XV       1
# 3  XTC2       1
# 4  XTC1       1

# %%
# if counts <= 1 for each node_id then any represenative will do
pd.concat([pd.read_sql(f"""
SELECT '{key}' as key,
        COUNT(DISTINCT({key})) as counts,
        "GID"
    FROM nodes
    GROUP BY "GID"
    ORDER BY COUNT(DISTINCT({key})) DESC
""", con).head(1) for key in columns_nodes[1:]])
# Out:
#            key  counts        GID
# 0          GID       1         YI
# 0      defline       1  ATMG01410
# 0      symbols       1  ATMG01410
# 0        names       1  ATMG01410
# 0    KO_effect       1  AT5G67590
# 0           GO       1         YI
# 0       GOdesc       1         YI
# 0  mapman_code       1  ATMG01410
# 0  mapman_name       1  ATMG01410
# 0  mapman_desc       1  ATMG01410

# %%
catted = pd.read_sql("""SELECT * from nodes""", con)
catted.tail(10)
# Out:
#        index        GID defline symbols names KO_effect    GO GOdesc  \
# 39809  39809  AT4G09895    None    None  None      None  None   None
# 39810  39810  AT4G09905    None    None  None      None  None   None
# 39811  39811  AT4G09915    None    None  None      None  None   None
# 39812  39812  AT4G09925    None    None  None      None  None   None
# 39813  39813  AT4G09935    None    None  None      None  None   None
# 39814  39814  AT4G09945    None    None  None      None  None   None
# 39815  39815  AT4G09955    None    None  None      None  None   None
# 39816  39816  AT4G09975    None    None  None      None  None   None
# 39817  39817  AT4G09985    None    None  None      None  None   None
# 39818  39818  AT4G09995    None    None  None      None  None   None
#
#       mapman_code           mapman_name  \
# 39809        35.2  not assigned.unknown
# 39810        35.2  not assigned.unknown
# 39811        35.2  not assigned.unknown
# 39812        35.2  not assigned.unknown
# 39813        35.2  not assigned.unknown
# 39814        35.2  not assigned.unknown
# 39815        35.2  not assigned.unknown
# 39816        35.2  not assigned.unknown
# 39817        35.2  not assigned.unknown
# 39818        35.2  not assigned.unknown
#
#                                              mapman_desc
# 39809                                 long noncoding RNA
# 39810                                 long noncoding RNA
# 39811                                 long noncoding RNA
# 39812                                        microRNA NA
# 39813                                 long noncoding RNA
# 39814                                 long noncoding RNA
# 39815  Natural antisense transcript overlaps with AT4...
# 39816  Natural antisense transcript overlaps with AT4...
# 39817  Natural antisense transcript overlaps with AT4...
# 39818                                 long noncoding RNA

# %% [markdown]
# ***
# Did this actually solve the problem? That is, `ATCG00690` is not in the merged nodes table csv.

# %%
problem_gene = pd.read_sql("""SELECT * from nodes where "GID"="ATCG00690" """, con)
problem_gene
# Out:
#    index        GID                                   defline       symbols  \
# 0  33392  ATCG00690  photosystem II reaction center protein T  PSBT | PSBTC
#
#                                         names KO_effect  \
# 0  photosystem II reaction center protein T |      None
#
#                                                   GO  \
# 0  GO:0015979|GO:0016168|GO:0009523|GO:0009535|GO...
#
#                                               GOdesc mapman_code  \
# 0  photosynthesis|chlorophyll binding|photosystem...     1.1.1.2
#
#                                          mapman_name  \
# 0  PS.lightreaction.photosystem II.PSII polypepti...
#
#                                 mapman_desc
# 0  photosystem II reaction center protein T

# %% [markdown]
# Yes. Yes it did. *phew*

# %% [markdown]
# ***

# %%
print(f"""'{"', '".join(sorted(('AT1G18590', 'AT2G34420', 'AT5G05850', 'ATCG00280', 'ATCG00350', 'ATCG00680', 'ATCG00690')))}'""")
# Out:
# 'AT1G18590', 'AT2G34420', 'AT5G05850', 'ATCG00280', 'ATCG00350', 'ATCG00680', 'ATCG00690'

# %%
node_checks = ('AT1G18590', 'AT2G34420', 'AT5G05850', 'ATCG00280', 'ATCG00350', 'ATCG00680', 'ATCG00690')
checks = pd.read_sql(f"""SELECT * from nodes where "GID" in ("{'", "'.join(node_checks)}")""", con)
print(f"{len(node_checks)} checks, {len(checks.values)} results")
assert len(node_checks) == len(checks.values)
# Out:
# 7 checks, 7 results

# %%
checks
# Out:
#    index        GID                                            defline  \
# 0   2012  AT1G18590                                sulfotransferase 17
# 1  12372  AT2G34420  photosystem II light harvesting complex gene B1B2
# 2  26367  AT5G05850        plant intracellular ras group-related LRR 1
# 3  33351  ATCG00280           photosystem II reaction center protein C
# 4  33358  ATCG00350                   Photosystem I, PsaA/PsaB protein
# 5  33391  ATCG00680           photosystem II reaction center protein B
# 6  33392  ATCG00690           photosystem II reaction center protein T
#
#                     symbols  \
# 0  ATSOT17 | ATST5C | SOT17
# 1          LHB1B2 | LHCB1.5
# 2                     PIRL1
# 3                      PSBC
# 4                      PSAA
# 5                      PSBB
# 6              PSBT | PSBTC
#
#                                                names KO_effect  \
# 0  SULFOTRANSFERASE 17 | ARABIDOPSIS SULFOTRANSFE...      None
# 1  photosystem II light harvesting complex gene B...      None
# 2        plant intracellular ras group-related LRR 1      None
# 3           photosystem II reaction center protein C      None
# 4                                               None      None
# 5           photosystem II reaction center protein B      None
# 6         photosystem II reaction center protein T |      None
#
#                                                   GO  \
# 0  GO:0005634|GO:0051923|GO:0008146|GO:0005737|GO...
# 1  GO:0009941|GO:0009507|GO:0009535|GO:0009768|GO...
# 2                   GO:0009555|GO:0055046|GO:0005886
# 3  GO:0010287|GO:0009534|GO:0009535|GO:0019684|GO...
# 4  GO:0009535|GO:0009536|GO:0009534|GO:0009579|GO...
# 5  GO:0009535|GO:0003729|GO:0010207|GO:0009534|GO...
# 6  GO:0015979|GO:0016168|GO:0009523|GO:0009535|GO...
#
#                                               GOdesc mapman_code  \
# 0  nucleus|sulfation|sulfotransferase activity|cy...       26.25
# 1  chloroplast envelope|chloroplast|chloroplast t...     1.1.1.1
# 2  pollen development|microgametogenesis|plasma m...       30.99
# 3  plastoglobule|chloroplast thylakoid|chloroplas...     1.1.1.2
# 4  chloroplast thylakoid membrane|plastid|chlorop...     1.1.2.2
# 5  chloroplast thylakoid membrane|mRNA binding|ph...     1.1.1.2
# 6  photosynthesis|chlorophyll binding|photosystem...     1.1.1.2
#
#                                          mapman_name  \
# 0                              misc.sulfotransferase
# 1             PS.lightreaction.photosystem II.LHC-II
# 2                             signalling.unspecified
# 3  PS.lightreaction.photosystem II.PSII polypepti...
# 4  PS.lightreaction.photosystem I.PSI polypeptide...
# 5  PS.lightreaction.photosystem II.PSII polypepti...
# 6  PS.lightreaction.photosystem II.PSII polypepti...
#
#                                          mapman_desc
# 0                                sulfotransferase 17
# 1  photosystem II light harvesting complex protei...
# 2        plant intracellular ras group-related LRR 1
# 3           photosystem II reaction center protein C
# 4                 Photosystem I%2C PsaA/PsaB protein
# 5           photosystem II reaction center protein B
# 6           photosystem II reaction center protein T
